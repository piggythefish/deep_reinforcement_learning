# %%
import numpy as np
import matplotlib.pyplot as plt
from gridworld import DetrministicGridworld

# %%
mdp = DetrministicGridworld(6, 6, walls=[(2, 2), (2, 3)], traps=[
                            (5, 2)], trap_reward=-1)
mdp.visualize()
mdp.run()
# Out:
# Simulate: 100%|██████████| 10000/10000 [00:00<00:00, 40309.65it/s]

# %%
ani = mdp.animate_episode(start_point=(0,2))
ani.save("ani.gif", savefig_kwargs={"facecolor" : (1,1,1,1)})
ani.save("ani.mp4")
