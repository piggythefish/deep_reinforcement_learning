# %%
import numpy as np
import matplotlib.pyplot as plt
from gridworld import DetrministicGridWorld

# %%
mdp = DetrministicGridWorld(6, 6, walls=[(2, 2), (2, 3)], traps=[
                            (5, 2)], trap_reward=-1)
mdp.visualize(savefig = True)
mdp.run(savefig=True)
# Out:
# Simulate: 100%|██████████| 10000/10000 [00:00<00:00, 38548.82it/s]

# %%
ani = mdp.animate_episode(start_point=(0,2), nbuffer= 60)
ani.save("ani.gif", savefig_kwargs={"facecolor" : (1,1,1,1)}, fps = 30)
ani.save("ani.mp4", fps=30)
